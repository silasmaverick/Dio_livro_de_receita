# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('/home/silas/Documentos/Governança/Curso/poetry_data_governance/base.csv',';')

# profile report na variável profile
# Out:
# /home/silas/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# profile report na variável profile
profile = ProfileReport(df, title="Profiling base bolsa familia",html={'style':{'full_width':True}})

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
profile.to_file("profiling_base_bolsa_familia.html")
# Out:
# Summarize dataset:   0%|          | 0/36 [00:35<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 profile.to_file("profiling_base_bolsa_familia.html")
#
# File ~/Documentos/Governança/Curso/poetry_data_governance/.venv/lib/python3.8/site-packages/pandas_profiling/profile_report.py:257, in ProfileReport.to_file(self, output_file, silent)
#     254         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     255     create_html_assets(self.config, output_file)
# --> 257 data = self.to_html()
#     259 if output_file.suffix != ".html":
#     260     suffix = output_file.suffix
#
# File ~/Documentos/Governança/Curso/poetry_data_governance/.venv/lib/python3.8/site-packages/pandas_profiling/profile_report.py:368, in ProfileReport.to_html(self)
#     360 def to_html(self) -> str:
# ...
